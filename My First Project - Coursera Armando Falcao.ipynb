# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Armando da Rocha Falcão Bandeira**
# Assessor Técnico no Departamento de Gestão de Carreira - Dataprev

# %% [markdown]
# _I am interested in data science because I want to improve my analytics skills_

# %% [markdown]
# ### In the code bellow we can see the “Hello, World!” sentence. It is a classic and time-honored tradition in computer programming.

# %%
print("Hello, Wordl!")
# Out:
# Hello, Wordl!

# %% [markdown]
# ***
#
# > Blockquote
#
# | Column 1      | Column 2      | Column 3 |
# | ------------- |:-------------:| -----   :|
# | Cell 1        | Cell 2        | Cell 3   |
#
# [Link with a tutorial that explains the code in cell 5](https://www.digitalocean.com/community/tutorials/how-to-write-your-first-python-3-program)
